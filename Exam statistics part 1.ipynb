# %% [markdown]
# COURSE EXAM STATISTICS

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("Real Estate Florida.csv",skiprows=4, header=0)
df = df.drop(columns = ["Unnamed: 0"])
df['Price'] = df['Price'].str.replace('$', '')
df['Price'] = df['Price'].str.replace(',', '')
df['Price'] = df['Price'].astype(int)

df
# Out:
# C:\Users\Sua\AppData\Local\Temp\ipykernel_10036\1209422765.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price'] = df['Price'].str.replace('$', '')
#      Year of sale  Month of sale Type of property  Area (ft.)   Price Country  \
# 0            2005              9            House     1042.21  887889     USA
# 1            2007              3            House     2103.94  875352     USA
# 2            2005             12            House     1894.35  869057     USA
# 3            2006              5            House     1783.18  795017     USA
# 4            2007              5            House     1787.51  787143     USA
# ..            ...            ...              ...         ...     ...     ...
# 666          2006              7        Apartment     1296.68  126968     USA
# ...

# %%
df_o = df.loc[(df["Type of property"] == "Office")]
df_h = df.loc[(df["Type of property"] == "House")]
df_a = df.loc[(df["Type of property"] == "Apartment")]
# Out:
#      Year of sale  Month of sale Type of property  Area (ft.)   Price Country  \
# 125          2007              5           Office     1638.95  535764     USA
# 126          2007             12           Office     1962.83  535537     USA
# 133          2007              3           Office     1780.71  519517     USA
# 144          2007              9           Office     1574.95  506810     USA
# 155          2007              9           Office     1729.71  492612     USA
# ..            ...            ...              ...         ...     ...     ...
# 652          2004             10           Office      688.70  154481     USA
# 656          2008              4           Office     1106.28  149709     USA
# 661          2004              4           Office      620.70  134618     USA
# 663          2004              2           Office      538.70  132611     USA
# 667          2004              3           Office      510.70  116973     USA
#
#        State Mortgage
# ...

# %%
plt.hist(df_o['Price'], bins=30)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of Office')
plt.show()

# %%
plt.hist(df_h['Price'], bins=30)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of House')
plt.show()

# %%
plt.hist(df_a['Price'], bins=30)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of Appartment')
plt.show()

#Appartment[$297,669] Office [$116,937]

# %%
df_o.plot.scatter(x='Area (ft.)', y='Price')
plt.xlabel('Area (ft.)')
plt.ylabel('Price')
plt.title('Price vs Area Office')
plt.show()

# %%
df_h.plot.scatter(x='Area (ft.)', y='Price')
plt.xlabel('Area (ft.)')
plt.ylabel('Price')
plt.title('Price vs Area House')
plt.show()

# %%
df_a.plot.scatter(x='Area (ft.)', y='Price')
plt.xlabel('Area (ft.)')
plt.ylabel('Price')
plt.title('Price vs Area Office')
plt.show()

# %%
print(df_o['Price'].skew())
print(df_h['Price'].skew())
print(df_a['Price'].skew())
# Out:
# 0.9355085022797704
# -1.0898189948198995
# 1.3502055429287283

# %%
print(df['Price'].mean())
print(df['Price'].median())
print(df['Price'].mode())
# Out:
# 359823.15797317435
# 290615.0
# 0    272450
# 1    290793
# 2    761413
# 3    763365
# Name: Price, dtype: int32

# %%
print("Oficce")
print(df_o['Price'].cov(df['Area (ft.)']))
print(df_o['Price'].corr(df['Area (ft.)']))
# Out:
# 26389567.80941081
# 0.8515429608311147

# %%
print("House")
print(df_h['Price'].cov(df['Area (ft.)']))
print(df_h['Price'].corr(df['Area (ft.)']))
# Out:
# 10897089.726274632
# 0.23186547395535523

# %%
print("Appartment")
print(df_a['Price'].cov(df['Area (ft.)']))
print(df_a['Price'].corr(df['Area (ft.)']))
# Out:
# Appartment
# 24880800.231764533
# 0.7722898322639604
